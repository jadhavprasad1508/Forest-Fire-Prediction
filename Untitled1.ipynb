# %% [markdown]
# Algerian Forest Fires Dataset
# Data Set Information:
#
# The dataset includes 244 instances that regroup a data of two regions of Algeria,namely the Bejaia region located in the northeast of Algeria and the Sidi Bel-abbes region located in the northwest of Algeria.
#
# 122 instances for each region.
#
# The period from June 2012 to September 2012. The dataset includes 11 attribues and 1 output attribue (class) The 244 instances have been classified into fire(138 classes) and not fire (106 classes) classes.

# %% [markdown]
# Attribute Information:
#
# Date : (DD/MM/YYYY) Day, month ('june' to 'september'), year (2012) Weather data observations
# Temp : temperature noon (temperature max) in Celsius degrees: 22 to 42
# RH : Relative Humidity in %: 21 to 90
# Ws :Wind speed in km/h: 6 to 29
# Rain: total day in mm: 0 to 16.8 FWI Components
# Fine Fuel Moisture Code (FFMC) index from the FWI system: 28.6 to 92.5
# Duff Moisture Code (DMC) index from the FWI system: 1.1 to 65.9
# Drought Code (DC) index from the FWI system: 7 to 220.4
# Initial Spread Index (ISI) index from the FWI system: 0 to 18.5
# Buildup Index (BUI) index from the FWI system: 1.1 to 68
# Fire Weather Index (FWI) Index: 0 to 31.1
# Classes: two classes, namely Fire and not Fire

# %%
# !pip install matplotlib seaborn
# Out:
# Requirement already satisfied: matplotlib in c:\users\dell\.conda\envs\forestfire\lib\site-packages (3.10.7)
# Requirement already satisfied: seaborn in c:\users\dell\.conda\envs\forestfire\lib\site-packages (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\.conda\envs\forestfire\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\.conda\envs\forestfire\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\.conda\envs\forestfire\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dell\.conda\envs\forestfire\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\dell\appdata\roaming\python\python310\site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\.conda\envs\forestfire\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\dell\.conda\envs\forestfire\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\dell\.conda\envs\forestfire\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\appdata\roaming\python\python310\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\users\dell\appdata\roaming\python\python310\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\appdata\roaming\python\python310\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\appdata\roaming\python\python310\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dataset=pd.read_csv('Algerian_forest_fires_dataset_UPDATE.csv' ,header=1)

# %%
dataset.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.0+ KB

# %% [markdown]
# ## Data Cleaning

# %%
## missing values
dataset[dataset.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 167                             14    07  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 167  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %% [markdown]
# The dataset is converted into two sets based on Region from 122th index, we can make a new column based on the Region
#
# 1 : "Bejaia Region Dataset"
#
# 2 : "Sidi-Bel Abbes Region Dataset"
#
# Add new column with region

# %%
dataset.loc[:122,"Region"]=0
dataset.loc[122:,"Region"]=1
df=dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
#  14  Region       246 non-null    float64
# dtypes: float64(1), object(14)
# memory usage: 29.0+ KB

# %%
df[['Region']]=df[['Region']].astype(int)

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes    Region
# 0  not fire          0
# 1  not fire          0
# 2  not fire          0
# 3  not fire          0
# 4  not fire          0

# %%
df.isnull().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# Region         0
# dtype: int64

# %%
## Removing the null values
df=df.dropna().reset_index(drop=True)

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes    Region
# 0  not fire          0
# 1  not fire          0
# 2  not fire          0
# 3  not fire          0
# 4  not fire          0

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# dtype: int64

# %%
df.iloc[[122]]
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI  \
# 122  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI
#
#      FWI  Classes    Region
# 122  FWI  Classes         1

# %%
##remove the 122nd row
df=df.drop(122).reset_index(drop=True)

# %%
df.iloc[[122]]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC   DC  ISI  BUI  FWI  \
# 122  01    06  2012          32  71  12   0.7  57.1  2.5  8.2  0.6  2.8  0.2
#
#        Classes    Region
# 122  not fire          1

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ', 'Region'],
#       dtype='object')

# %%
 ## Removing spaces from columns
df.columns=df.columns.str.strip()
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    object
#  1   month        243 non-null    object
#  2   year         243 non-null    object
#  3   Temperature  243 non-null    object
#  4   RH           243 non-null    object
#  5   Ws           243 non-null    object
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: int64(1), object(14)
# memory usage: 28.6+ KB

# %%
## change the required parameters into int
df[['month','year','Temperature','RH','Ws']]=df[['month','year','Temperature','RH','Ws']].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    object
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: int64(6), object(9)
# memory usage: 28.6+ KB

# %%
## changing to float
objects=[features for features in df.columns if df[features].dtypes=='O']

# %%
for i in objects:
    if i!='Classes':
        df[i]=df[i].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    float64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: float64(8), int64(6), object(1)
# memory usage: 28.6+ KB

# %%
objects
# Out:
# ['day', 'Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes']

# %%
df.describe()
# Out:
#               day       month    year  Temperature          RH          Ws  \
# count  243.000000  243.000000   243.0   243.000000  243.000000  243.000000
# mean    15.761317    7.502058  2012.0    32.152263   62.041152   15.493827
# std      8.842552    1.114793     0.0     3.628039   14.828160    2.811385
# min      1.000000    6.000000  2012.0    22.000000   21.000000    6.000000
# 25%      8.000000    7.000000  2012.0    30.000000   52.500000   14.000000
# 50%     16.000000    8.000000  2012.0    32.000000   63.000000   15.000000
# 75%     23.000000    8.000000  2012.0    35.000000   73.500000   17.000000
# max     31.000000    9.000000  2012.0    42.000000   90.000000   29.000000
#
#              Rain        FFMC         DMC          DC         ISI         BUI  \
# count  243.000000  243.000000  243.000000  243.000000  243.000000  243.000000
# mean     0.762963   77.842387   14.680658   49.430864    4.742387   16.690535
# std      2.003207   14.349641   12.393040   47.665606    4.154234   14.228421
# min      0.000000   28.600000    0.700000    6.900000    0.000000    1.100000
# 25%      0.000000   71.850000    5.800000   12.350000    1.400000    6.000000
# 50%      0.000000   83.300000   11.300000   33.100000    3.500000   12.400000
# 75%      0.500000   88.300000   20.800000   69.100000    7.250000   22.650000
# max     16.800000   96.000000   65.900000  220.400000   19.000000   68.000000
#
#               FWI      Region
# count  243.000000  243.000000
# mean     7.035391    0.497942
# std      7.440568    0.501028
# min      0.000000    0.000000
# 25%      0.700000    0.000000
# 50%      4.200000    0.000000
# 75%     11.450000    1.000000
# max     31.100000    1.000000

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0  1.0      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1  2.0      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2  3.0      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3  4.0      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4  5.0      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3  0.0  not fire          0
# 4  0.5  not fire          0

# %%
## saving cleaned data 
df.to_csv('Cleaned Algerian Dataset.csv',index=False)

# %%
df_copy=df.drop(['day','month','year'],axis=1)

# %%
df_copy.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI      Classes  \
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5  not fire
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4  not fire
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0  not fire
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5  not fire
#
#    Region
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
# Make sure df_copy is created as a DataFrame explicitly
df_copy.tail()
# Out:
#       day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI  \
# 238  26.0      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5
# 239  27.0      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1
# 240  28.0      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4
# 241  29.0      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7
# 242  30.0      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2
#
#       BUI  FWI  Classes  Region
# 238  16.9  6.5        1       1
# 239   6.2  0.0        0       1
# 240   3.4  0.2        0       1
# 241   5.1  0.7        0       1
# 242   4.8  0.5        0       1

# %%
print("--- Columns BEFORE drop ---")
print(df_index.columns)
# Out:
# --- Columns BEFORE drop ---
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[118], line 2
#       1 print("--- Columns BEFORE drop ---")
# ----> 2 print(df_index.columns)
#
# NameError: name 'df_index' is not defined

# %%
# Now run your encoding line
df_copy['Classes'] = np.where(df_copy['Classes'].str.contains('not fire'), 0, 1)

# %%
df_copy.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0  1.0      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1  2.0      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2  3.0      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3  4.0      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4  5.0      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI  Classes  Region
# 0  0.5        0       0
# 1  0.4        0       0
# 2  0.1        0       0
# 3  0.0        0       0
# 4  0.5        0       0

# %%
df_copy.tail()
# Out:
#       day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI  \
# 238  26.0      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5
# 239  27.0      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1
# 240  28.0      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4
# 241  29.0      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7
# 242  30.0      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2
#
#       BUI  FWI  Classes  Region
# 238  16.9  6.5        1       1
# 239   6.2  0.0        0       1
# 240   3.4  0.2        0       1
# 241   5.1  0.7        0       1
# 242   4.8  0.5        0       1

# %%
df_copy['Classes'].value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\dell\.conda\envs\forestfire\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\dell\appdata\roaming\python\python310\site-packages (from seaborn) (2.2.6)
# Requirement already satisfied: pandas>=1.2 in c:\users\dell\appdata\roaming\python\python310\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\dell\.conda\envs\forestfire\lib\site-packages (from seaborn) (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\.conda\envs\forestfire\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\.conda\envs\forestfire\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\.conda\envs\forestfire\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dell\.conda\envs\forestfire\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\.conda\envs\forestfire\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\dell\.conda\envs\forestfire\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\dell\.conda\envs\forestfire\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\appdata\roaming\python\python310\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\appdata\roaming\python\python310\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
import seaborn as sns

# %%
## Plot density plot for all features
plt.style.use('seaborn-v0_8') # <--- FIX IS HERE
df_copy.hist(bins=50,figsize=(20,15))
plt.show()

# %%
## Percentage of fire
percentage=df_copy['Classes'].value_counts(normalize=True)*100

# %%
## Pie chart of percentage
classlabels=["Fire","Not fire"]
plt.figure(figsize=(12,7))
plt.pie(percentage,labels=classlabels,autopct='%1